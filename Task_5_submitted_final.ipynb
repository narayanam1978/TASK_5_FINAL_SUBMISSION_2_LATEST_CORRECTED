# %%
#Task-5 D20 batch Ranganadh Narayanam Due 10/04/2022 Submission date: 10/04/2022:

# %%
#reading "takehome_user_engagement.csv" file. an intermediary step. 
import pandas as pd
df_firstn = pd.read_csv("takehome_user_engagement.csv")
df_firstn
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30        1        1
# 1       2013-11-15 03:45:04        2        1
# 2       2013-11-29 03:45:04        2        1
# 3       2013-12-09 03:45:04        2        1
# 4       2013-12-25 03:45:04        2        1
# ...                     ...      ...      ...
# 207912  2013-09-06 06:14:15    11996        1
# 207913  2013-01-15 18:28:37    11997        1
# 207914  2014-04-27 12:45:16    11998        1
# 207915  2012-06-02 11:55:59    11999        1
# 207916  2014-01-26 08:57:12    12000        1
#
# [207917 rows x 3 columns]

# %%
#reading "takehome_users.csv" file. a complementary step. first 11 rows
import pandas as pd
df_firstn1 = pd.read_csv("takehome_users.csv",nrows=11)
df_firstn1
# Out:
#     object_id     creation_time               name  \
# 0           1  22-04-2014 03:53     Clausen August
# 1           2  15-11-2013 03:45      Poole Matthew
# 2           3  19-03-2013 23:14  Bottrill Mitchell
# 3           4  21-05-2013 08:09    Clausen Nicklas
# 4           5  17-01-2013 10:14          Raw Grace
# 5           6  17-12-2013 03:37      Cunha Eduardo
# 6           7  16-12-2012 13:24       Sewell Tyler
# 7           8  31-07-2013 05:34  Hamilton Danielle
# 8           9  05-11-2013 04:04         Amsel Paul
# 9          10  16-01-2013 22:08       Santos Carla
# 10         11  26-12-2013 03:55     Paulsen Malthe
#
#                             email    creation_source  \
# 0        AugustCClausen@yahoo.com       GUEST_INVITE
# 1          MatthewPoole@gustr.com         ORG_INVITE
# 2      MitchellBottrill@gustr.com         ORG_INVITE
# 3       NicklasSClausen@yahoo.com       GUEST_INVITE
# 4              GraceRaw@yahoo.com       GUEST_INVITE
# ...

# %%
#reading total "takehome_users.csv"  
import pandas as pd
takehome_users=pd.read_csv('takehome_users.csv', sep=',' , encoding='latin-1')
takehome_users
# Out:
#        object_id     creation_time               name  \
# 0              1  22-04-2014 03:53     Clausen August
# 1              2  15-11-2013 03:45      Poole Matthew
# 2              3  19-03-2013 23:14  Bottrill Mitchell
# 3              4  21-05-2013 08:09    Clausen Nicklas
# 4              5  17-01-2013 10:14          Raw Grace
# ...          ...               ...                ...
# 11995      11996  06-09-2013 06:14       Meier Sophia
# 11996      11997  10-01-2013 18:28      Fisher Amelie
# 11997      11998  27-04-2014 12:45        Haynes Jake
# 11998      11999  31-05-2012 11:55       Faber Annett
# 11999      12000  26-01-2014 08:57         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
#To indetifying how many "GUEST_INVITE" are there
df100 = takehome_users
df101 = df100[(df100['creation_source'] == 'GUEST_INVITE')]
df101
# Out:
#        object_id     creation_time               name  \
# 0              1  22-04-2014 03:53     Clausen August
# 3              4  21-05-2013 08:09    Clausen Nicklas
# 4              5  17-01-2013 10:14          Raw Grace
# 5              6  17-12-2013 03:37      Cunha Eduardo
# 16            17  09-04-2014 14:39   Reynolds Anthony
# ...          ...               ...                ...
# 11970      11971  04-05-2013 06:54  Ferreira Beatrice
# 11974      11975  23-03-2013 11:10     Daecher Jürgen
# 11980      11981  05-03-2013 01:53          Fry Tyler
# 11993      11994  05-06-2012 04:46     Grimstone Joel
# 11997      11998  27-04-2014 12:45        Haynes Jake
#
#                                    email creation_source  \
# 0               AugustCClausen@yahoo.com    GUEST_INVITE
# 3              NicklasSClausen@yahoo.com    GUEST_INVITE
# 4                     GraceRaw@yahoo.com    GUEST_INVITE
# 5          EduardoPereiraCunha@yahoo.com    GUEST_INVITE
# ...

# %%
#To indetifying how many "ORG_INVITE" are there
df100 = takehome_users
df101 = df100[(df100['creation_source'] == 'ORG_INVITE')]
df101
# Out:
#        object_id     creation_time                 name  \
# 1              2  15-11-2013 03:45        Poole Matthew
# 2              3  19-03-2013 23:14    Bottrill Mitchell
# 9             10  16-01-2013 22:08         Santos Carla
# 11            12  17-04-2014 23:48      Mathiesen Lærke
# 12            13  30-03-2014 16:19        Fry Alexander
# ...          ...               ...                  ...
# 11971      11972  13-09-2012 23:23      Penington Jamie
# 11979      11980  02-02-2014 15:23  Gloeckner Franziska
# 11981      11982  06-12-2013 14:39        Barajas Maria
# 11989      11990  05-07-2013 21:00            Juhl Aase
# 11995      11996  06-09-2013 06:14         Meier Sophia
#
#                                email creation_source  \
# 1             MatthewPoole@gustr.com      ORG_INVITE
# 2         MitchellBottrill@gustr.com      ORG_INVITE
# 9      CarlaFerreiraSantos@gustr.com      ORG_INVITE
# 11         LaerkeLMathiesen@cuvox.de      ORG_INVITE
# ...

# %%
#To indetifying how many "PERSONAL_PROJECTS" are there
df100 = takehome_users
df101 = df100[(df100['creation_source'] == 'PERSONAL_PROJECTS')]
df101
# Out:
#        object_id     creation_time               name  \
# 7              8  31-07-2013 05:34  Hamilton Danielle
# 8              9  05-11-2013 04:04         Amsel Paul
# 14            15  16-07-2013 21:33        Theiss Ralf
# 15            16  11-02-2013 10:09         Engel René
# 20            21  22-01-2013 12:27       Hunter Alfie
# ...          ...               ...                ...
# 11987      11988  15-03-2014 11:04        Minick John
# 11991      11992  09-04-2014 19:39   Hermansen Amanda
# 11992      11993  28-03-2013 23:24    Townsend Isabel
# 11994      11995  21-10-2013 13:33   Werfel Sebastian
# 11998      11999  31-05-2012 11:55       Faber Annett
#
#                             email    creation_source  \
# 7      DanielleHamilton@yahoo.com  PERSONAL_PROJECTS
# 8           PaulAmsel@hotmail.com  PERSONAL_PROJECTS
# 14         RalfTheiss@hotmail.com  PERSONAL_PROJECTS
# 15          ReneEngel@hotmail.com  PERSONAL_PROJECTS
# ...

# %%
#To indetifying how many "SIGNUP" are there
df100 = takehome_users
df101 = df100[(df100['creation_source'] == 'SIGNUP')]
df101
# Out:
#        object_id     creation_time            name  \
# 6              7  16-12-2012 13:24    Sewell Tyler
# 10            11  26-12-2013 03:55  Paulsen Malthe
# 13            14  11-10-2012 16:14     Rivera Bret
# 18            19  24-05-2013 14:56  Collins Arlene
# 19            20  06-03-2014 11:46   Helms Mikayla
# ...          ...               ...             ...
# 11973      11974  26-12-2012 16:42     Scott James
# 11978      11979  28-01-2013 09:26    Hurst Harley
# 11983      11984  11-02-2014 21:26      Reed Cerys
# 11986      11987  15-03-2013 03:21      Reed Poppy
# 11999      12000  26-01-2014 08:57      Lima Thaís
#
#                             email creation_source  last_session_creation_time  \
# 6      TylerSewell@jourrapide.com          SIGNUP                1.356010e+09
# 10       MaltheAPaulsen@gustr.com          SIGNUP                1.388117e+09
# 13          BretKRivera@gmail.com          SIGNUP                1.350058e+09
# ...

# %%
#To indetifying how many "SIGNUP_GOOGLE_AUTH" are there
df100 = takehome_users
df101 = df100[(df100['creation_source'] == 'SIGNUP_GOOGLE_AUTH')]
df101
# Out:
#        object_id     creation_time             name  \
# 44            45  29-04-2014 21:55  Boxer Gabrielle
# 54            55  18-07-2012 23:00    Castro Arthur
# 58            59  07-03-2014 03:21   Barbosa Ágatha
# 60            61  14-05-2014 03:45      Melo Murilo
# 62            63  20-12-2012 16:30   Martins Leonor
# ...          ...               ...              ...
# 11982      11983  30-07-2013 00:23       Engel Mike
# 11985      11986  24-06-2012 01:02    Ribeiro Clara
# 11988      11989  02-09-2013 11:24   Pereira Emilly
# 11990      11991  20-04-2014 14:22    Vaughn Arthur
# 11996      11997  10-01-2013 18:28    Fisher Amelie
#
#                                    email     creation_source  \
# 44              GabrielleBoxer@gmail.com  SIGNUP_GOOGLE_AUTH
# 54         ArthurPereiraCastro@gmail.com  SIGNUP_GOOGLE_AUTH
# 58     AgathaCavalcantiBarbosa@gmail.com  SIGNUP_GOOGLE_AUTH
# 60           MuriloCorreiaMelo@gmail.com  SIGNUP_GOOGLE_AUTH
# ...

# %%
#reading takehome_user_engagement.csv
import pandas as pd
df_firstn = pd.read_csv("takehome_user_engagement.csv")#.tail(12000)
df_firstn
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30        1        1
# 1       2013-11-15 03:45:04        2        1
# 2       2013-11-29 03:45:04        2        1
# 3       2013-12-09 03:45:04        2        1
# 4       2013-12-25 03:45:04        2        1
# ...                     ...      ...      ...
# 207912  2013-09-06 06:14:15    11996        1
# 207913  2013-01-15 18:28:37    11997        1
# 207914  2014-04-27 12:45:16    11998        1
# 207915  2012-06-02 11:55:59    11999        1
# 207916  2014-01-26 08:57:12    12000        1
#
# [207917 rows x 3 columns]

# %%
df_firstn.shape
# Out:
# (207917, 3)

# %%
#to identify how many user_id 2 are there a com0lementary step. 
K1 = df_firstn[(df_firstn['user_id'] == 2)]
K1
# Out:
#              time_stamp  user_id  visited
# 1   2013-11-15 03:45:04        2        1
# 2   2013-11-29 03:45:04        2        1
# 3   2013-12-09 03:45:04        2        1
# 4   2013-12-25 03:45:04        2        1
# 5   2013-12-31 03:45:04        2        1
# 6   2014-01-08 03:45:04        2        1
# 7   2014-02-03 03:45:04        2        1
# 8   2014-02-08 03:45:04        2        1
# 9   2014-02-09 03:45:04        2        1
# 10  2014-02-13 03:45:04        2        1
# 11  2014-02-16 03:45:04        2        1
# 12  2014-03-09 03:45:04        2        1
# 13  2014-03-13 03:45:04        2        1
# 14  2014-03-31 03:45:04        2        1

# %%
#comlementary step
K2 = K1.shape
A1 = []
A1.append(K2[0])
A1
# Out:
# [14]

# %%
#to identify which is the maximum occurance of which user_id from "takehome_user_engagement.csv". 
#found to be "user ID: index 3622+1 = 3623 is occuring the max number of times 606. 
#For that user ID to find which "creation_source
B1 = []
for i in range(12000):
    K1 = df_firstn[(df_firstn['user_id'] == i+1)]
    K2 = K1.shape    
    B1.append(K2[0])
print(len(B1)) 
print(max(B1))
print(B1.index(max(B1)))
B2 = B1.copy()
B2.sort(reverse = True)
# Out:
# 12000
# 606
# 3622

# %%
#printing first 10 high frequent user_id s in "takehome_user_engagement.csv" for finding their "creation_source"
B2 = B1.copy()
B2.sort(reverse = True)
for i in range(10):
    print(B2[i],B1.index(B2[i])+1)
# Out:
# 606 3623
# 600 906
# 593 1811
# 590 7590
# 585 8068
# 581 9402
# 580 4022
# 566 3269
# 547 9312
# 545 7210

# %%
import pandas as pd
takehome_users=pd.read_csv('takehome_users.csv', sep=',' , encoding='latin-1')
takehome_users
# Out:
#        object_id     creation_time               name  \
# 0              1  22-04-2014 03:53     Clausen August
# 1              2  15-11-2013 03:45      Poole Matthew
# 2              3  19-03-2013 23:14  Bottrill Mitchell
# 3              4  21-05-2013 08:09    Clausen Nicklas
# 4              5  17-01-2013 10:14          Raw Grace
# ...          ...               ...                ...
# 11995      11996  06-09-2013 06:14       Meier Sophia
# 11996      11997  10-01-2013 18:28      Fisher Amelie
# 11997      11998  27-04-2014 12:45        Haynes Jake
# 11998      11999  31-05-2012 11:55       Faber Annett
# 11999      12000  26-01-2014 08:57         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
#For that user ID:3623 to find which "creation_source. It is found to be "ORG_INVITE" is most dominant
df100 = takehome_users
df1010 = df100[(df100['invited_by_user_id'] == 3623)]
df1010
# Out:
#        object_id     creation_time                name  \
# 2653        2654  12-12-2013 17:48          Lack Tyson
# 3622        3623  25-06-2012 14:34        Melo Vitória
# 4217        4218  20-01-2014 07:46        Vanzant Nina
# 5772        5773  09-04-2014 01:20    Pritchard Sheryl
# 6392        6393  07-09-2013 19:47  Robertson Virginia
# 11386      11387  26-07-2012 06:32    Gärtner Michelle
#
#                                  email creation_source  \
# 2653               TysonLack@yahoo.com    GUEST_INVITE
# 3622   VitoriaAlvesMelo@jourrapide.com      ORG_INVITE
# 4217       NinaWVanzant@jourrapide.com    GUEST_INVITE
# 5772      SherylJPritchard@hotmail.com      ORG_INVITE
# 6392       VirginiaTRobertson@cuvox.de      ORG_INVITE
# 11386        MichelleGartner@gmail.com      ORG_INVITE
#
#        last_session_creation_time  opted_in_to_mailing_list  \
# 2653                 1.386871e+09                         0
# 3622                 1.401201e+09                         0
# ...

# %%
#For that user ID:906 to find which "creation_source. It is found to be "ORG_INVITE" is most dominant
df100 = takehome_users
df1010 = df100[(df100['invited_by_user_id'] == 906)]
df1010
# Out:
#       object_id     creation_time          name                       email  \
# 1412       1413  21-04-2014 12:16  Almeida Kauã  KauaSilvaAlmeida@yahoo.com
# 8957       8958  08-08-2013 04:52      Hart Mia      MiaHart@jourrapide.com
#
#      creation_source  last_session_creation_time  opted_in_to_mailing_list  \
# 1412      ORG_INVITE                         NaN                         1
# 8957      ORG_INVITE                         NaN                         0
#
#       enabled_for_marketing_drip  org_id  invited_by_user_id
# 1412                           0     358               906.0
# 8957                           0     358               906.0

# %%
#For that user ID:1811 to find which "creation_source. It is found to be "ORG_INVITE" is most dominant
df100 = takehome_users
df1010 = df100[(df100['invited_by_user_id'] == 1811)]
df1010
# Out:
#        object_id     creation_time             name  \
# 1381        1382  23-09-2012 09:03   Castro Eduarda
# 9378        9379  13-06-2013 07:38    Robson Finley
# 9540        9541  04-10-2013 20:17    Thornton Inez
# 10529      10530  20-03-2014 08:05  Jeppesen Andrea
#
#                                 email creation_source  \
# 1381   EduardaRochaCastro@hotmail.com    GUEST_INVITE
# 9378           FinleyRobson@yahoo.com      ORG_INVITE
# 9540          InezJThornton@gustr.com      ORG_INVITE
# 10529       AndreaCJeppesen@yahoo.com      ORG_INVITE
#
#        last_session_creation_time  opted_in_to_mailing_list  \
# 1381                 1.348391e+09                         0
# 9378                 1.371109e+09                         1
# 9540                 1.380918e+09                         0
# 10529                         NaN                         1
#
#        enabled_for_marketing_drip  org_id  invited_by_user_id
# ...

# %%
#For that user ID:7590 to find which "creation_source. It is found to be "ORG_INVITE" is most dominant
df100 = takehome_users
df1010 = df100[(df100['invited_by_user_id'] == 7590)]
df1010
# Out:
#       object_id     creation_time         name                      email  \
# 3177       3178  11-04-2014 22:49  Gomes Clara  ClaraSilvaGomes@gmail.com
#
#      creation_source  last_session_creation_time  opted_in_to_mailing_list  \
# 3177    GUEST_INVITE                1.401145e+09                         1
#
#       enabled_for_marketing_drip  org_id  invited_by_user_id
# 3177                           1     225              7590.0

# %%
#For that user ID:8068 to find which "creation_source. It is found to be "ORG_INVITE" is most dominant
df100 = takehome_users
df1010 = df100[(df100['invited_by_user_id'] == 8068)]
df1010
# Out:
#        object_id     creation_time                name  \
# 121          122  18-03-2013 07:10  Schreiber Christin
# 853          854  06-09-2013 23:06       Poulsen Oskar
# 1844        1845  11-01-2014 03:04    Schuster Dominik
# 3813        3814  23-11-2012 03:49           Konig Uta
# 5259        5260  02-04-2013 15:04        Tyler Maisie
# 7264        7265  03-03-2013 10:46        Frame Audrey
# 8067        8068  01-06-2012 20:02         McCoy Donna
# 8727        8728  06-06-2013 22:24           Lamb Owen
# 9362        9363  21-12-2012 19:02       Nielsen Sille
# 11488      11489  04-04-2014 20:42     Kennedy Michele
#
#                                email creation_source  \
# 121    ChristinSchreiber@hotmail.com    GUEST_INVITE
# 853           OskarFPoulsen@cuvox.de      ORG_INVITE
# 1844       DominikSchuster@yahoo.com      ORG_INVITE
# 3813              UtaKonig@gustr.com    GUEST_INVITE
# 5259              kwhucbwh@swgoa.com      ORG_INVITE
# ...

# %%
#For that user ID:9402 to find which "creation_source. It is found to be "ORG_INVITE" is most dominant
df100 = takehome_users
df1010 = df100[(df100['invited_by_user_id'] == 9402)]
df1010
# Out:
#      object_id     creation_time         name               email  \
# 878        879  13-06-2012 04:43  Coe Dorothy  fhwlqxql@gwqoy.com
#
#     creation_source  last_session_creation_time  opted_in_to_mailing_list  \
# 878    GUEST_INVITE                         NaN                         1
#
#      enabled_for_marketing_drip  org_id  invited_by_user_id
# 878                           1     317              9402.0

# %%
#For that user ID:4022 to find which "creation_source. It is found to be "ORG_INVITE" is most dominant
df100 = takehome_users
df1010 = df100[(df100['invited_by_user_id'] == 4022)]
df1010
# Out:
#       object_id     creation_time            name                      email  \
# 5959       5960  22-03-2013 16:51  McLucas Cooper  CooperMcLucas@hotmail.com
#
#      creation_source  last_session_creation_time  opted_in_to_mailing_list  \
# 5959      ORG_INVITE                1.368291e+09                         1
#
#       enabled_for_marketing_drip  org_id  invited_by_user_id
# 5959                           1       8              4022.0

# %%
#For that user ID:3269 to find which "creation_source. It is found to be "ORG_INVITE" is most dominant
df100 = takehome_users
df1010 = df100[(df100['invited_by_user_id'] == 3269)]
df1010
# Out:
#        object_id     creation_time             name  \
# 3268        3269  03-09-2012 01:03    Outtrim Gemma
# 8979        8980  11-11-2012 19:30  Mikkelsen Sofie
# 11205      11206  27-10-2013 06:57    Hamilton Owen
#
#                              email creation_source  \
# 3268   GemmaOuttrim@jourrapide.com    GUEST_INVITE
# 8979            kpvieunf@nwybj.com    GUEST_INVITE
# 11205           yybgblfr@uwbnp.com    GUEST_INVITE
#
#        last_session_creation_time  opted_in_to_mailing_list  \
# 3268                 1.401844e+09                         1
# 8979                          NaN                         1
# 11205                1.397286e+09                         0
#
#        enabled_for_marketing_drip  org_id  invited_by_user_id
# 3268                            1     148              3269.0
# 8979                            0     148              3269.0
# 11205                           0     148              3269.0

# %%
#For that user ID:9312 to find which "creation_source. It is found to be "ORG_INVITE" is most dominant
df100 = takehome_users
df1010 = df100[(df100['invited_by_user_id'] == 9312)]
df1010
# Out:
#       object_id     creation_time              name  \
# 85           86  11-11-2012 02:50  Barbosa Nicolash
# 3924       3925  08-05-2013 08:26       Jessen Adam
#
#                                         email creation_source  \
# 85    NicolashFernandesBarbosa@jourrapide.com      ORG_INVITE
# 3924                    AdamMJessen@gmail.com      ORG_INVITE
#
#       last_session_creation_time  opted_in_to_mailing_list  \
# 85                  1.352861e+09                         0
# 3924                1.368174e+09                         0
#
#       enabled_for_marketing_drip  org_id  invited_by_user_id
# 85                             0     249              9312.0
# 3924                           0     249              9312.0

# %%
#For that user ID:7210 to find which "creation_source. It is found to be "ORG_INVITE" is most dominant
df100 = takehome_users
df1010 = df100[(df100['invited_by_user_id'] == 7210)]
df1010
# Out:
#       object_id     creation_time              name  \
# 3799       3800  17-02-2013 22:52       Barbosa Kai
# 6174       6175  05-11-2012 14:46          Skov Ida
# 6198       6199  16-02-2014 00:18  Spedding Brayden
# 7209       7210  12-08-2012 19:17   Herzog Benjamin
#
#                                email creation_source  \
# 3799  KaiOliveiraBarbosa@hotmail.com      ORG_INVITE
# 6174              IdaFSkov@yahoo.com      ORG_INVITE
# 6198  BraydenSpedding@jourrapide.com      ORG_INVITE
# 7209        BenjaminHerzog@gustr.com      ORG_INVITE
#
#       last_session_creation_time  opted_in_to_mailing_list  \
# 3799                1.361574e+09                         0
# 6174                1.352213e+09                         1
# 6198                1.392510e+09                         0
# 7209                1.401909e+09                         0
#
#       enabled_for_marketing_drip  org_id  invited_by_user_id
# 3799                           0     243              7210.0
# ...

# %%
import pandas as pd
df_firstn = pd.read_csv("takehome_user_engagement.csv")#.tail(12000)
df_firstn
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30        1        1
# 1       2013-11-15 03:45:04        2        1
# 2       2013-11-29 03:45:04        2        1
# 3       2013-12-09 03:45:04        2        1
# 4       2013-12-25 03:45:04        2        1
# ...                     ...      ...      ...
# 207912  2013-09-06 06:14:15    11996        1
# 207913  2013-01-15 18:28:37    11997        1
# 207914  2014-04-27 12:45:16    11998        1
# 207915  2012-06-02 11:55:59    11999        1
# 207916  2014-01-26 08:57:12    12000        1
#
# [207917 rows x 3 columns]

# %%
K1 = df_firstn[(df_firstn['user_id'] == 3623)]
K1[0:20]
# Out:
#                 time_stamp  user_id  visited
# 62717  2012-06-27 14:34:33     3623        1
# 62718  2012-07-01 14:34:33     3623        1
# 62719  2012-07-02 14:34:33     3623        1
# 62720  2012-07-04 14:34:33     3623        1
# 62721  2012-07-08 14:34:33     3623        1
# 62722  2012-07-13 14:34:33     3623        1
# 62723  2012-07-14 14:34:33     3623        1
# 62724  2012-07-21 14:34:33     3623        1
# 62725  2012-07-23 14:34:33     3623        1
# 62726  2012-07-24 14:34:33     3623        1
# 62727  2012-07-26 14:34:33     3623        1
# 62728  2012-08-03 14:34:33     3623        1
# 62729  2012-08-05 14:34:33     3623        1
# 62730  2012-08-06 14:34:33     3623        1
# 62731  2012-08-07 14:34:33     3623        1
# 62732  2012-08-10 14:34:33     3623        1
# 62733  2012-08-11 14:34:33     3623        1
# 62734  2012-08-12 14:34:33     3623        1
# 62735  2012-08-14 14:34:33     3623        1
# 62736  2012-08-20 14:34:33     3623        1
